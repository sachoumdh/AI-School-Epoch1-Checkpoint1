# %%
# Exo 1 
print ("Please give your sentence :")
sentence = input()
print ("The sentence you entered :", sentence)
print ("The sentence in lower case :", sentence.lower())

# %%
# Exo 2
print ("Please give your sentence :")
sentence = input()
print ("The sentence you entered :", sentence)
print ("The sentence with spaces replaced by underscores :", sentence.replace(" ", "__" ))

# %%
# Exo 3
c = 300000000
print ("Please give a mass in kilograms :")
mass = input()

E = ( int(mass) * c ) ** 2 

print ("The energy corresponding to a mass of", mass, "kg is", E, "Joules")
# Out:
# Please give a mass in kilograms :
# The mass you entered : 30
# The energy corresponding to a mass of 30 kg is 81000000000000000000 Joules
